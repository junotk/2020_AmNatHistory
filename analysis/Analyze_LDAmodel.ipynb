# %%
import numpy as np
import pandas as pd
import math
import logging
import pickle
import gensim
from gensim import corpora
from tqdm import tqdm
from wordcloud import WordCloud
import matplotlib
import matplotlib.pylab as plt
import pyLDAvis
import pyLDAvis.gensim
pyLDAvis.enable_notebook()

# %%
df = pd.read_csv('../data/AmNat_allAbstracts.csv')
df = df.dropna(subset=['Abstract','Title'])
df = df.reset_index()

# %%
with open('corpus.pkl', 'rb') as f:
    corpus = pickle.load(f)

lda_model = gensim.models.ldamodel.LdaModel.load('lda_t17.model')

# %%
# assign topic vector for each document
num_topics = lda_model.num_topics
topics = [lda_model[c] for c in corpus]

dense = np.zeros( (len(topics), num_topics), float)
for ti,t in enumerate(topics):
    for tj,v in t:
        dense[ti,tj] = v

# %%
transpose = dense.transpose()
top10 = [np.argsort(column)[::-1][0:9] for column in transpose] # top10 documents for each topic

# %%
docs_by_topics = pd.DataFrame({
    'Topic 0':df['Title'][top10[0]].values.tolist(),
    'Topic 2':df['Title'][top10[2]].values.tolist(),
    'Topic 3':df['Title'][top10[3]].values.tolist(),
    'Topic 6':df['Title'][top10[6]].values.tolist(),
    'Topic 11':df['Title'][top10[11]].values.tolist(),
    'Topic 16':df['Title'][top10[16]].values.tolist()
})

# %%
docs_by_topics.T.to_csv('docs_by_topics.csv')

# %%
from scipy.spatial import distance
pairwise = distance.squareform(distance.pdist(dense))

largest = pairwise.max()
for ti in range(len(topics)):
    pairwise[ti,ti] = largest + 1
    
def closest_to(doc_id):
    return pairwise[doc_id].argmin()

# %%
targets= df.index[range(10)]
match = [closest_to(t) for t in targets]
comparison = pd.DataFrame({
    'Target_Index':df['index'][targets],
    'Traget_Title':df['Title'][targets],
    'Target_Abstract':df['Abstract'][targets],
    'Matching_Index':[df['index'][d] for d in match],
    'Matching_Title':[df['Title'][d] for d in match],
    'Matching_Abstract':[df['Abstract'][d] for d in match]
})
# comparison.to_csv('comparison.csv')

# %%
comparison
# Out:
#    Target_Index                                       Traget_Title  \
# 0             0  Experimental Hybridization Studies Suggest Tha...
# 1             1  The Ecology of Individual Differences Empirica...
# 2             3  Floral Trait Evolution of Angiosperms on Pacif...
# 3             4  Looking for Mimicry in a Snake Assemblage Usin...
# 4             5  Correlated Evolution of Sex Allocation and Mat...
# 5             6  Climate Change and Thermoregulatory Consequenc...
# 6             7  Optimal Network Architectures for Spatially St...
# 7             8  Dispersal Predicts Hybrid Zone Widths across A...
# 8             9  Where Is Natural History in Ecological, Evolut...
# 9            10  Species Differences in Phenology Shape Coexist...
#
#                                      Target_Abstract  Matching_Index  \
# 0  The alleles used for adaptation can pleiotropi...            1810
# 1  Movement provides a link between individual be...            4361
# 2  Animals frequently evolve unique suites of tra...            8008
# 3  Batesian mimicry is a canonical example of evo...            2234
# 4  In accordance with predictions of the size-adv...            5736
# 5  Activity times structure the thermal environme...            6190
# 6  The motivation of this article is to derive ne...            1256
# 7  Hybrid zones occur as range boundaries for man...            5690
# 8  Natural history is the careful observation of ...            2149
# 9  Ecological theory produces opposing prediction...            1360
#
#                                       Matching_Title  \
# 0  Selection, Epistasis, and Parent-of-Origin Eff...
# 1  THE TIME-SCALE PROBLEM IN EXPLOITER-VICTIM MOD...
# 2  AN ANALYTICAL STUDY OF THE GEOGRAPHIC DISTRIBU...
# 3      Predator-dependent species-area relationships
# 4  BALANCED SEX-RATIOS IN DIMORPHIC ALTRICIAL BIR...
# 5  GEOGRAPHIC ANALYSIS OF THERMAL EQUILIBRIA - A ...
# 6  Beyond the Competition-Colonization Trade-Off:...
# 7  THE INTRODUCED HAWAIIAN AVIFAUNA - BIOGEOGRAPH...
# 8  Predation-competition interactions for seasona...
# 9  Successional Dynamics in the Seasonally Forced...
#
#                                    Matching_Abstract
# 0  Understanding the nature of selection against ...
# 1  Standard exploiter-victim models assume an ins...
# 2  Where moisture is a limiting factor, xerophyti...
# 3  In addition to having a positive effect on spe...
# 4  Sex ratio theory holds that the population sex...
# 5  Adult body size and fecundity of several speci...
# 6  Disturbances' role in shaping communities is w...
# 7  We discuss the patterns of introduction and ex...
# 8  We investigate the interacting effects of pred...
# 9  Plankton seasonal succession is a classic exam...
